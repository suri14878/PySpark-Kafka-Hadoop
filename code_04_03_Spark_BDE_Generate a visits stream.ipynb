# %% [markdown]
# ### Create a stream of website visits records

# %%
from kafka import KafkaProducer
import datetime
import random
import json
import time

visits_topic="spark.streaming.website.visits"

def string_serializer(value):
    return value.encode('utf-8')
    
visits_producer=KafkaProducer( 
                bootstrap_servers=["localhost:9092"],
                key_serializer=string_serializer,
                value_serializer=string_serializer
                )

countries = ["USA","India","Brazil","Australia","Russia"]
last_actions = ["Catalog","FAQ","Order","ShoppingCart"]

#Generate 100 sample visit records
for i in range(1,100):

    #Create a json string with generated data
    json_record={}
    json_record["country"]=countries[random.randint(0,4)]
    json_record["last_action"]=last_actions[random.randint(0,3)]
    json_record["visit_date"]=datetime.datetime.today().strftime("%Y-%m-%d %H:%M:%S")
    json_record["duration"]=random.randint(1,20)

    #Use country as Key. Each country will go through the same partition, 
    #hence updates to a given country can be handled sequencially
    kafka_key=json_record["country"]
    kafka_value = json.dumps(json_record)
    print(kafka_value)
    visits_producer.send(visits_topic, key=kafka_key,value=kafka_value)

    #sleep for 1-3 seconds
    time.sleep(random.randint(1,3))

visits_producer.flush()
visits_producer.close()
# Out:
# {"country": "Russia", "last_action": "FAQ", "visit_date": "2026-01-01 17:45:48", "duration": 20}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2026-01-01 17:45:50", "duration": 10}
# {"country": "India", "last_action": "Catalog", "visit_date": "2026-01-01 17:45:53", "duration": 16}
# {"country": "Russia", "last_action": "Catalog", "visit_date": "2026-01-01 17:45:56", "duration": 4}
# {"country": "Australia", "last_action": "ShoppingCart", "visit_date": "2026-01-01 17:45:59", "duration": 5}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2026-01-01 17:46:01", "duration": 12}
# {"country": "India", "last_action": "Order", "visit_date": "2026-01-01 17:46:04", "duration": 9}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2026-01-01 17:46:05", "duration": 9}
# {"country": "USA", "last_action": "FAQ", "visit_date": "2026-01-01 17:46:06", "duration": 1}
# {"country": "USA", "last_action": "Catalog", "visit_date": "2026-01-01 17:46:09", "duration": 5}
# {"country": "Australia", "last_action": "FAQ", "visit_date": "2026-01-01 17:46:10", "duration": 10}
# {"country": "USA", "last_action": "Catalog", "visit_date": "2026-01-01 17:46:12", "duration": 18}
# {"country": "Russia", "last_action": "Catalog", "visit_date": "2026-01-01 17:46:13", "duration": 20}
# {"country": "Russia", "last_action": "Order", "visit_date": "2026-01-01 17:46:16", "duration": 9}
# {"country": "Australia", "last_action": "FAQ", "visit_date": "2026-01-01 17:46:17", "duration": 9}
# {"country": "USA", "last_action": "ShoppingCart", "visit_date": "2026-01-01 17:46:20", "duration": 18}
# {"country": "USA", "last_action": "Catalog", "visit_date": "2026-01-01 17:46:23", "duration": 18}
# {"country": "USA", "last_action": "ShoppingCart", "visit_date": "2026-01-01 17:46:26", "duration": 16}
# {"country": "Russia", "last_action": "Catalog", "visit_date": "2026-01-01 17:46:27", "duration": 9}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2026-01-01 17:46:28", "duration": 4}
# {"country": "Australia", "last_action": "ShoppingCart", "visit_date": "2026-01-01 17:46:31", "duration": 12}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2026-01-01 17:46:33", "duration": 17}
# {"country": "India", "last_action": "Catalog", "visit_date": "2026-01-01 17:46:34", "duration": 4}
# {"country": "India", "last_action": "FAQ", "visit_date": "2026-01-01 17:46:36", "duration": 16}
# {"country": "Brazil", "last_action": "Catalog", "visit_date": "2026-01-01 17:46:39", "duration": 20}
# {"country": "India", "last_action": "Catalog", "visit_date": "2026-01-01 17:46:41", "duration": 20}
# {"country": "Australia", "last_action": "FAQ", "visit_date": "2026-01-01 17:46:44", "duration": 7}
# {"country": "USA", "last_action": "ShoppingCart", "visit_date": "2026-01-01 17:46:45", "duration": 12}
# {"country": "India", "last_action": "Order", "visit_date": "2026-01-01 17:46:47", "duration": 2}
# {"country": "Russia", "last_action": "Order", "visit_date": "2026-01-01 17:46:50", "duration": 5}
# {"country": "India", "last_action": "Order", "visit_date": "2026-01-01 17:46:53", "duration": 8}
# {"country": "USA", "last_action": "ShoppingCart", "visit_date": "2026-01-01 17:46:56", "duration": 9}
# {"country": "Russia", "last_action": "FAQ", "visit_date": "2026-01-01 17:46:58", "duration": 17}
# {"country": "USA", "last_action": "FAQ", "visit_date": "2026-01-01 17:47:00", "duration": 3}
# {"country": "India", "last_action": "Order", "visit_date": "2026-01-01 17:47:02", "duration": 8}
# {"country": "Brazil", "last_action": "FAQ", "visit_date": "2026-01-01 17:47:05", "duration": 4}
# {"country": "India", "last_action": "Order", "visit_date": "2026-01-01 17:47:07", "duration": 6}
# {"country": "Russia", "last_action": "FAQ", "visit_date": "2026-01-01 17:47:08", "duration": 6}
# {"country": "Russia", "last_action": "FAQ", "visit_date": "2026-01-01 17:47:09", "duration": 8}
# {"country": "Brazil", "last_action": "Catalog", "visit_date": "2026-01-01 17:47:11", "duration": 19}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2026-01-01 17:47:14", "duration": 14}
# {"country": "Brazil", "last_action": "Order", "visit_date": "2026-01-01 17:47:15", "duration": 9}
# {"country": "Russia", "last_action": "ShoppingCart", "visit_date": "2026-01-01 17:47:17", "duration": 5}
# {"country": "Russia", "last_action": "FAQ", "visit_date": "2026-01-01 17:47:20", "duration": 12}
# {"country": "Russia", "last_action": "Catalog", "visit_date": "2026-01-01 17:47:23", "duration": 20}
# {"country": "Australia", "last_action": "FAQ", "visit_date": "2026-01-01 17:47:24", "duration": 6}
# {"country": "Russia", "last_action": "Order", "visit_date": "2026-01-01 17:47:25", "duration": 20}
# {"country": "India", "last_action": "FAQ", "visit_date": "2026-01-01 17:47:26", "duration": 15}
# {"country": "Australia", "last_action": "Order", "visit_date": "2026-01-01 17:47:27", "duration": 4}
# {"country": "Russia", "last_action": "Catalog", "visit_date": "2026-01-01 17:47:30", "duration": 19}
# {"country": "USA", "last_action": "ShoppingCart", "visit_date": "2026-01-01 17:47:32", "duration": 12}
# {"country": "Brazil", "last_action": "Catalog", "visit_date": "2026-01-01 17:47:34", "duration": 7}
# {"country": "Russia", "last_action": "FAQ", "visit_date": "2026-01-01 17:47:35", "duration": 12}
# {"country": "Australia", "last_action": "ShoppingCart", "visit_date": "2026-01-01 17:47:36", "duration": 3}
# {"country": "Russia", "last_action": "Order", "visit_date": "2026-01-01 17:47:37", "duration": 2}
# {"country": "Australia", "last_action": "Order", "visit_date": "2026-01-01 17:47:38", "duration": 1}
# {"country": "Russia", "last_action": "ShoppingCart", "visit_date": "2026-01-01 17:47:40", "duration": 5}
# {"country": "Russia", "last_action": "FAQ", "visit_date": "2026-01-01 17:47:41", "duration": 3}
# {"country": "USA", "last_action": "Order", "visit_date": "2026-01-01 17:47:42", "duration": 2}
# {"country": "USA", "last_action": "ShoppingCart", "visit_date": "2026-01-01 17:47:43", "duration": 15}
# {"country": "Brazil", "last_action": "FAQ", "visit_date": "2026-01-01 17:47:46", "duration": 16}
# {"country": "Australia", "last_action": "Order", "visit_date": "2026-01-01 17:47:48", "duration": 19}
# {"country": "Brazil", "last_action": "Catalog", "visit_date": "2026-01-01 17:47:51", "duration": 7}
# {"country": "Australia", "last_action": "FAQ", "visit_date": "2026-01-01 17:47:53", "duration": 19}
# {"country": "Brazil", "last_action": "Catalog", "visit_date": "2026-01-01 17:47:56", "duration": 8}
# {"country": "Australia", "last_action": "Catalog", "visit_date": "2026-01-01 17:47:59", "duration": 17}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 39
#      36     visits_producer.send(visits_topic, key=kafka_key,value=kafka_value)
#      38     #sleep for 1-3 seconds
# ---> 39     time.sleep(random.randint(1,3))
#      41 visits_producer.flush()
#      42 visits_producer.close()
#
# KeyboardInterrupt:

# %%
from kafka import KafkaConsumer
import uuid

def string_deserializer(value):
    return value.decode("utf-8") if value is not None else None

group = f"visit-consumer-test-{uuid.uuid4()}"

consumer = KafkaConsumer(
    visits_topic,
    bootstrap_servers=["localhost:9092"],
    value_deserializer=string_deserializer,
    auto_offset_reset="earliest",
    enable_auto_commit=False,
    group_id=group,
)

# poll a few times to allow partition assignment
for _ in range(5):
    msgs = consumer.poll(timeout_ms=2000)
    total = sum(len(v) for v in msgs.values())
    if total:
        break

print("Group:", group)
print("Total messages:", total)

for tp, records in msgs.items():
    for r in records:
        print(f"{tp.topic}:{tp.partition}:{r.offset} value={r.value}")
# Out:
# Group: visit-consumer-test-ac09e616-399d-4b44-a18f-a49837f3d3fc
# Total messages: 99
# spark.streaming.website.visits:0:0 value={"country": "USA", "last_action": "Catalog", "visit_date": "2025-12-31 19:44:53", "duration": 19}
# spark.streaming.website.visits:0:1 value={"country": "Brazil", "last_action": "Order", "visit_date": "2025-12-31 19:44:54", "duration": 9}
# spark.streaming.website.visits:0:2 value={"country": "Brazil", "last_action": "Catalog", "visit_date": "2025-12-31 19:44:55", "duration": 5}
# spark.streaming.website.visits:0:3 value={"country": "Brazil", "last_action": "FAQ", "visit_date": "2025-12-31 19:44:57", "duration": 8}
# spark.streaming.website.visits:0:4 value={"country": "Russia", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:45:00", "duration": 11}
# spark.streaming.website.visits:0:5 value={"country": "Australia", "last_action": "FAQ", "visit_date": "2025-12-31 19:45:03", "duration": 7}
# spark.streaming.website.visits:0:6 value={"country": "Brazil", "last_action": "Order", "visit_date": "2025-12-31 19:45:04", "duration": 1}
# spark.streaming.website.visits:0:7 value={"country": "India", "last_action": "FAQ", "visit_date": "2025-12-31 19:45:06", "duration": 16}
# spark.streaming.website.visits:0:8 value={"country": "USA", "last_action": "Catalog", "visit_date": "2025-12-31 19:45:09", "duration": 13}
# spark.streaming.website.visits:0:9 value={"country": "Russia", "last_action": "FAQ", "visit_date": "2025-12-31 19:45:10", "duration": 9}
# spark.streaming.website.visits:0:10 value={"country": "Brazil", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:45:11", "duration": 5}
# spark.streaming.website.visits:0:11 value={"country": "Russia", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:45:14", "duration": 7}
# spark.streaming.website.visits:0:12 value={"country": "Brazil", "last_action": "Catalog", "visit_date": "2025-12-31 19:45:17", "duration": 19}
# spark.streaming.website.visits:0:13 value={"country": "Brazil", "last_action": "FAQ", "visit_date": "2025-12-31 19:45:20", "duration": 15}
# spark.streaming.website.visits:0:14 value={"country": "Russia", "last_action": "Order", "visit_date": "2025-12-31 19:45:22", "duration": 2}
# spark.streaming.website.visits:0:15 value={"country": "India", "last_action": "Catalog", "visit_date": "2025-12-31 19:45:23", "duration": 4}
# spark.streaming.website.visits:0:16 value={"country": "Russia", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:45:26", "duration": 10}
# spark.streaming.website.visits:0:17 value={"country": "Australia", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:45:27", "duration": 11}
# spark.streaming.website.visits:0:18 value={"country": "Brazil", "last_action": "FAQ", "visit_date": "2025-12-31 19:45:30", "duration": 7}
# spark.streaming.website.visits:0:19 value={"country": "Australia", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:45:31", "duration": 16}
# spark.streaming.website.visits:0:20 value={"country": "Brazil", "last_action": "Catalog", "visit_date": "2025-12-31 19:45:33", "duration": 12}
# spark.streaming.website.visits:0:21 value={"country": "Brazil", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:45:34", "duration": 7}
# spark.streaming.website.visits:0:22 value={"country": "USA", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:45:37", "duration": 4}
# spark.streaming.website.visits:0:23 value={"country": "Australia", "last_action": "FAQ", "visit_date": "2025-12-31 19:45:40", "duration": 1}
# spark.streaming.website.visits:0:24 value={"country": "India", "last_action": "Order", "visit_date": "2025-12-31 19:45:41", "duration": 2}
# spark.streaming.website.visits:0:25 value={"country": "Brazil", "last_action": "Order", "visit_date": "2025-12-31 19:45:42", "duration": 17}
# spark.streaming.website.visits:0:26 value={"country": "USA", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:45:44", "duration": 10}
# spark.streaming.website.visits:0:27 value={"country": "Russia", "last_action": "FAQ", "visit_date": "2025-12-31 19:45:47", "duration": 16}
# spark.streaming.website.visits:0:28 value={"country": "USA", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:45:49", "duration": 6}
# spark.streaming.website.visits:0:29 value={"country": "Russia", "last_action": "Catalog", "visit_date": "2025-12-31 19:45:50", "duration": 7}
# spark.streaming.website.visits:0:30 value={"country": "Australia", "last_action": "Catalog", "visit_date": "2025-12-31 19:45:52", "duration": 11}
# spark.streaming.website.visits:0:31 value={"country": "Russia", "last_action": "Catalog", "visit_date": "2025-12-31 19:45:53", "duration": 10}
# spark.streaming.website.visits:0:32 value={"country": "USA", "last_action": "Catalog", "visit_date": "2025-12-31 19:45:54", "duration": 2}
# spark.streaming.website.visits:0:33 value={"country": "Brazil", "last_action": "Order", "visit_date": "2025-12-31 19:45:57", "duration": 3}
# spark.streaming.website.visits:0:34 value={"country": "Brazil", "last_action": "FAQ", "visit_date": "2025-12-31 19:45:58", "duration": 7}
# spark.streaming.website.visits:0:35 value={"country": "Brazil", "last_action": "Catalog", "visit_date": "2025-12-31 19:45:59", "duration": 15}
# spark.streaming.website.visits:0:36 value={"country": "India", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:46:01", "duration": 6}
# spark.streaming.website.visits:0:37 value={"country": "Australia", "last_action": "FAQ", "visit_date": "2025-12-31 19:46:02", "duration": 14}
# spark.streaming.website.visits:0:38 value={"country": "India", "last_action": "FAQ", "visit_date": "2025-12-31 19:46:03", "duration": 10}
# spark.streaming.website.visits:0:39 value={"country": "USA", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:46:05", "duration": 15}
# spark.streaming.website.visits:0:40 value={"country": "Brazil", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:46:06", "duration": 18}
# spark.streaming.website.visits:0:41 value={"country": "Brazil", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:46:07", "duration": 11}
# spark.streaming.website.visits:0:42 value={"country": "India", "last_action": "FAQ", "visit_date": "2025-12-31 19:46:09", "duration": 17}
# spark.streaming.website.visits:0:43 value={"country": "India", "last_action": "FAQ", "visit_date": "2025-12-31 19:46:12", "duration": 13}
# spark.streaming.website.visits:0:44 value={"country": "Australia", "last_action": "FAQ", "visit_date": "2025-12-31 19:46:15", "duration": 15}
# spark.streaming.website.visits:0:45 value={"country": "USA", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:46:18", "duration": 17}
# spark.streaming.website.visits:0:46 value={"country": "Russia", "last_action": "Catalog", "visit_date": "2025-12-31 19:46:21", "duration": 15}
# spark.streaming.website.visits:0:47 value={"country": "Australia", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:46:23", "duration": 17}
# spark.streaming.website.visits:0:48 value={"country": "Brazil", "last_action": "Catalog", "visit_date": "2025-12-31 19:46:24", "duration": 15}
# spark.streaming.website.visits:0:49 value={"country": "Russia", "last_action": "Catalog", "visit_date": "2025-12-31 19:46:26", "duration": 12}
# spark.streaming.website.visits:0:50 value={"country": "Australia", "last_action": "Order", "visit_date": "2025-12-31 19:46:27", "duration": 4}
# spark.streaming.website.visits:0:51 value={"country": "Russia", "last_action": "Catalog", "visit_date": "2025-12-31 19:46:29", "duration": 8}
# spark.streaming.website.visits:0:52 value={"country": "Brazil", "last_action": "Order", "visit_date": "2025-12-31 19:46:32", "duration": 12}
# spark.streaming.website.visits:0:53 value={"country": "Australia", "last_action": "Catalog", "visit_date": "2025-12-31 19:46:35", "duration": 15}
# spark.streaming.website.visits:0:54 value={"country": "USA", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:46:36", "duration": 12}
# spark.streaming.website.visits:0:55 value={"country": "Australia", "last_action": "Order", "visit_date": "2025-12-31 19:46:39", "duration": 16}
# spark.streaming.website.visits:0:56 value={"country": "Russia", "last_action": "Order", "visit_date": "2025-12-31 19:46:41", "duration": 20}
# spark.streaming.website.visits:0:57 value={"country": "India", "last_action": "FAQ", "visit_date": "2025-12-31 19:46:42", "duration": 13}
# spark.streaming.website.visits:0:58 value={"country": "India", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:46:45", "duration": 16}
# spark.streaming.website.visits:0:59 value={"country": "Brazil", "last_action": "Catalog", "visit_date": "2025-12-31 19:46:48", "duration": 6}
# spark.streaming.website.visits:0:60 value={"country": "India", "last_action": "Catalog", "visit_date": "2025-12-31 19:46:49", "duration": 18}
# spark.streaming.website.visits:0:61 value={"country": "India", "last_action": "FAQ", "visit_date": "2025-12-31 19:46:51", "duration": 8}
# spark.streaming.website.visits:0:62 value={"country": "Brazil", "last_action": "Order", "visit_date": "2025-12-31 19:46:52", "duration": 1}
# spark.streaming.website.visits:0:63 value={"country": "Brazil", "last_action": "Catalog", "visit_date": "2025-12-31 19:46:55", "duration": 15}
# spark.streaming.website.visits:0:64 value={"country": "Australia", "last_action": "FAQ", "visit_date": "2025-12-31 19:46:58", "duration": 11}
# spark.streaming.website.visits:0:65 value={"country": "Brazil", "last_action": "FAQ", "visit_date": "2025-12-31 19:47:00", "duration": 5}
# spark.streaming.website.visits:0:66 value={"country": "USA", "last_action": "Catalog", "visit_date": "2025-12-31 19:47:03", "duration": 10}
# spark.streaming.website.visits:0:67 value={"country": "India", "last_action": "FAQ", "visit_date": "2025-12-31 19:47:06", "duration": 19}
# spark.streaming.website.visits:0:68 value={"country": "Australia", "last_action": "FAQ", "visit_date": "2025-12-31 19:47:09", "duration": 2}
# spark.streaming.website.visits:0:69 value={"country": "USA", "last_action": "Order", "visit_date": "2025-12-31 19:47:11", "duration": 17}
# spark.streaming.website.visits:0:70 value={"country": "Russia", "last_action": "Order", "visit_date": "2025-12-31 19:47:12", "duration": 11}
# spark.streaming.website.visits:0:71 value={"country": "Brazil", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:47:13", "duration": 1}
# spark.streaming.website.visits:0:72 value={"country": "Brazil", "last_action": "Order", "visit_date": "2025-12-31 19:47:15", "duration": 1}
# spark.streaming.website.visits:0:73 value={"country": "Brazil", "last_action": "Catalog", "visit_date": "2025-12-31 19:47:16", "duration": 1}
# spark.streaming.website.visits:0:74 value={"country": "Australia", "last_action": "FAQ", "visit_date": "2025-12-31 19:47:18", "duration": 15}
# spark.streaming.website.visits:0:75 value={"country": "Russia", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:47:20", "duration": 20}
# spark.streaming.website.visits:0:76 value={"country": "Russia", "last_action": "Catalog", "visit_date": "2025-12-31 19:47:22", "duration": 3}
# spark.streaming.website.visits:0:77 value={"country": "India", "last_action": "FAQ", "visit_date": "2025-12-31 19:47:24", "duration": 13}
# spark.streaming.website.visits:0:78 value={"country": "Brazil", "last_action": "FAQ", "visit_date": "2025-12-31 19:47:27", "duration": 15}
# spark.streaming.website.visits:0:79 value={"country": "Russia", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:47:29", "duration": 16}
# spark.streaming.website.visits:0:80 value={"country": "USA", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:47:32", "duration": 20}
# spark.streaming.website.visits:0:81 value={"country": "India", "last_action": "FAQ", "visit_date": "2025-12-31 19:47:34", "duration": 4}
# spark.streaming.website.visits:0:82 value={"country": "Brazil", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:47:35", "duration": 3}
# spark.streaming.website.visits:0:83 value={"country": "Australia", "last_action": "FAQ", "visit_date": "2025-12-31 19:47:38", "duration": 16}
# spark.streaming.website.visits:0:84 value={"country": "India", "last_action": "Order", "visit_date": "2025-12-31 19:47:39", "duration": 12}
# spark.streaming.website.visits:0:85 value={"country": "USA", "last_action": "Order", "visit_date": "2025-12-31 19:47:42", "duration": 14}
# spark.streaming.website.visits:0:86 value={"country": "Australia", "last_action": "Catalog", "visit_date": "2025-12-31 19:47:43", "duration": 2}
# spark.streaming.website.visits:0:87 value={"country": "Brazil", "last_action": "FAQ", "visit_date": "2025-12-31 19:47:44", "duration": 11}
# spark.streaming.website.visits:0:88 value={"country": "USA", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:47:46", "duration": 13}
# spark.streaming.website.visits:0:89 value={"country": "India", "last_action": "Catalog", "visit_date": "2025-12-31 19:47:47", "duration": 12}
# spark.streaming.website.visits:0:90 value={"country": "USA", "last_action": "Order", "visit_date": "2025-12-31 19:47:50", "duration": 3}
# spark.streaming.website.visits:0:91 value={"country": "Brazil", "last_action": "Order", "visit_date": "2025-12-31 19:47:53", "duration": 1}
# spark.streaming.website.visits:0:92 value={"country": "Australia", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:47:56", "duration": 11}
# spark.streaming.website.visits:0:93 value={"country": "Russia", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:47:59", "duration": 10}
# spark.streaming.website.visits:0:94 value={"country": "Russia", "last_action": "Order", "visit_date": "2025-12-31 19:48:00", "duration": 11}
# spark.streaming.website.visits:0:95 value={"country": "Brazil", "last_action": "Order", "visit_date": "2025-12-31 19:48:01", "duration": 16}
# spark.streaming.website.visits:0:96 value={"country": "Australia", "last_action": "ShoppingCart", "visit_date": "2025-12-31 19:48:03", "duration": 6}
# spark.streaming.website.visits:0:97 value={"country": "Brazil", "last_action": "Catalog", "visit_date": "2025-12-31 19:48:04", "duration": 7}
# spark.streaming.website.visits:0:98 value={"country": "Russia", "last_action": "FAQ", "visit_date": "2025-12-31 19:48:06", "duration": 9}
